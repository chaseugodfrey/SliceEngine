# %%
import json
from graphviz import Digraph

# %%
def visualize_fsm(json_path):
    with open(json_path, 'r') as f:
        data = json.load(f)

    dot = Digraph(comment='Character State Machine')
    dot.attr(rankdir='LR', size='12,12', overlap='false', splines='true')

    # 1. Mark the Entry State
    entry = data.get("entryState", "Idle")
    dot.node('ENTRY', shape='point')
    dot.edge('ENTRY', entry, label='start')

    # 2. Iterate through the stateMap
    state_map = data.get("stateMap", {})
    
    for state_name, state_data in state_map.items():
        # Style the nodes
        node_attr = {'shape': 'ellipse'}
        if state_name == "AnyState":
            node_attr = {'shape': 'doubleoctagon', 'color': 'red'}
        elif state_name == entry:
            node_attr = {'style': 'filled', 'fillcolor': 'lightblue'}
        
        dot.node(state_name, **node_attr)

        # 3. Process Transitions for this state
        transitions = state_data.get("transitions", [])
        for trans in transitions:
            target = trans.get("targetState")
            
            # Extract condition names as labels
            conditions = [c.get("paramName") for c in trans.get("conditions", [])]
            label = ", ".join(conditions) if conditions else "auto"
            
            # Add exit time info to label if applicable
            if trans.get("hasExitTime"):
                label += f" (Exit: {trans.get('exitTime')})"

            dot.edge(state_name, target, label=label)

    # Save and Render
    dot.render('game_fsm_output', format='png', cleanup=True)
    print("Graph generated: game_fsm_output.png")

# %%
visualize_fsm("Slice/SliceEditor/Assets/Default/DefaultController.controller")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# File ~\anaconda3\Lib\site-packages\graphviz\backend\execute.py:78, in run_check(cmd, input_lines, encoding, quiet, **kwargs)
#      77     else:
# ---> 78         proc = subprocess.run(cmd, **kwargs)
#      79 except OSError as e:
#
# File ~\anaconda3\Lib\subprocess.py:548, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     546     kwargs['stderr'] = PIPE
# --> 548 with Popen(*popenargs, **kwargs) as process:
#     549     try:
#
# File ~\anaconda3\Lib\subprocess.py:1026, in Popen.__init__(self, args, bufsize, executable, stdin, stdout, stderr, preexec_fn, close_fds, shell, cwd, env, universal_newlines, startupinfo, creationflags, restore_signals, start_new_session, pass_fds, user, group, extra_groups, encoding, errors, text, umask, pipesize, process_group)
# ...
